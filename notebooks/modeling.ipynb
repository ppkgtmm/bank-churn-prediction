# %% [markdown]
# ### Import libraries

# %%
import joblib
import pandas as pd
from numpy import arange
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report, make_scorer, recall_score
from constants import target_col as target_name, output_dir, model_fname, report_cmap, seed, read_config
from utilities import do_modeling, get_evaluation_report

# %% [markdown]
# ### Configure defaults

# %%
# column names
prediction_column = 'prediction'
target_col = [target_name]

# standardized datasets' path
train_std_path = './outputs/std/train.csv'
val_std_path = './outputs/std/validation.csv'
test_std_path = './outputs/std/test.csv'

# scaled datasets' path
train_mm_path = './outputs/min_max/train.csv'
val_mm_path = './outputs/min_max/validation.csv'
test_mm_path = './outputs/min_max/test.csv'

plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Read data

# %%
train_std = pd.read_csv(train_std_path, **read_config)
val_std = pd.read_csv(val_std_path, **read_config)
test_std = pd.read_csv(test_std_path, **read_config)

train_mm = pd.read_csv(train_mm_path, **read_config)
val_mm = pd.read_csv(val_mm_path, **read_config)
test_mm = pd.read_csv(test_mm_path, **read_config)

# %% [markdown]
# ### Data check

# %%
train_std.head()
# Out:
#            attrition_flag  gender_F  gender_M  education_level_College  \
# clientnum
# 779040408               0       0.0       1.0                      0.0
# 714212358               1       1.0       0.0                      0.0
# 714383583               0       1.0       0.0                      0.0
# 779536233               0       1.0       0.0                      0.0
# 720512433               1       0.0       1.0                      0.0
#
#            education_level_Doctorate  education_level_Graduate  \
# clientnum
# 779040408                        0.0                       0.0
# 714212358                        0.0                       0.0
# 714383583                        0.0                       0.0
# 779536233                        0.0                       1.0
# 720512433                        0.0                       0.0
#
#            education_level_High School  education_level_Post-Graduate  \
# clientnum
# 779040408                          1.0                            0.0
# 714212358                          1.0                            0.0
# 714383583                          0.0                            0.0
# 779536233                          0.0                            0.0
# 720512433                          0.0                            0.0
#
#            education_level_Uneducated  education_level_Unknown  ...  \
# clientnum                                                       ...
# 779040408                         0.0                      0.0  ...
# 714212358                         0.0                      0.0  ...
# 714383583                         0.0                      1.0  ...
# 779536233                         0.0                      0.0  ...
# 720512433                         1.0                      0.0  ...
#
#            total_relationship_count  months_inactive_12_mon  \
# clientnum
# 779040408                 -0.531190               -1.329577
# 714212358                 -1.823180                0.674102
# 714383583                  0.760799                0.674102
# 779536233                 -1.823180               -1.329577
# 720512433                  1.406794                1.675941
#
#            contacts_count_12_mon  credit_limit  total_revolving_bal  \
# clientnum
# 779040408              -0.410992      0.396539             0.670714
# 714212358              -0.410992     -0.369006             0.675630
# 714383583               0.494007      1.701759             0.663338
# 779536233              -1.315992     -0.791731            -0.682639
# 720512433               0.494007      0.732578             1.382422
#
#            total_amt_chng_q4_q1  total_trans_amt  total_trans_ct  \
# clientnum
# 779040408              0.339143        -0.855777       -1.343908
# 714212358             -1.818470        -0.661828       -0.328752
# 714383583              0.352770         1.237945        1.363175
# 779536233              1.093172         0.076291        0.771001
# 720512433              0.330059         0.939718        0.559510
#
#            total_ct_chng_q4_q1  avg_utilization_ratio
# clientnum
# 779040408            -0.882476              -0.483350
# 714212358            -0.146956               0.188227
# 714383583             0.797520              -0.735191
# 779536233             0.074536               0.531316
# 720512433             0.998116              -0.446851
#
# [5 rows x 23 columns]

# %%
train_mm.head()
# Out:
#            attrition_flag  gender_F  gender_M  education_level_College  \
# clientnum
# 779040408               0       0.0       1.0                      0.0
# 714212358               1       1.0       0.0                      0.0
# 714383583               0       1.0       0.0                      0.0
# 779536233               0       1.0       0.0                      0.0
# 720512433               1       0.0       1.0                      0.0
#
#            education_level_Doctorate  education_level_Graduate  \
# clientnum
# 779040408                        0.0                       0.0
# 714212358                        0.0                       0.0
# 714383583                        0.0                       0.0
# 779536233                        0.0                       1.0
# 720512433                        0.0                       0.0
#
#            education_level_High School  education_level_Post-Graduate  \
# clientnum
# 779040408                          1.0                            0.0
# 714212358                          1.0                            0.0
# 714383583                          0.0                            0.0
# 779536233                          0.0                            0.0
# 720512433                          0.0                            0.0
#
#            education_level_Uneducated  education_level_Unknown  ...  \
# clientnum                                                       ...
# 779040408                         0.0                      0.0  ...
# 714212358                         0.0                      0.0  ...
# 714383583                         0.0                      1.0  ...
# 779536233                         0.0                      0.0  ...
# 720512433                         1.0                      0.0  ...
#
#            total_relationship_count  months_inactive_12_mon  \
# clientnum
# 779040408                       0.4                0.166667
# 714212358                       0.0                0.500000
# 714383583                       0.8                0.500000
# 779536233                       0.0                0.166667
# 720512433                       1.0                0.666667
#
#            contacts_count_12_mon  credit_limit  total_revolving_bal  \
# clientnum
# 779040408               0.333333      0.324772             0.676202
# 714212358               0.333333      0.115537             0.677791
# 714383583               0.500000      0.681507             0.673818
# 779536233               0.166667      0.000000             0.238776
# 720512433               0.500000      0.416616             0.906238
#
#            total_amt_chng_q4_q1  total_trans_amt  total_trans_ct  \
# clientnum
# 779040408              0.245511         0.052802        0.178295
# 714212358              0.105681         0.089785        0.364341
# 714383583              0.246394         0.452044        0.674419
# 779536233              0.294377         0.230534        0.565891
# 720512433              0.244922         0.395177        0.527132
#
#            total_ct_chng_q4_q1  avg_utilization_ratio
# clientnum
# 779040408             0.140017               0.140704
# 714212358             0.189303               0.325628
# 714383583             0.252590               0.071357
# 779536233             0.204144               0.420101
# 720512433             0.266032               0.150754
#
# [5 rows x 23 columns]

# %%
print(
    'Standardized train set shape:', train_std.shape, 
    'validation set shape:', val_std.shape,
    'test set shape:', test_std.shape
)
print(
    'MinMax scaled train set shape:', train_mm.shape,
    'validation set shape:', val_mm.shape,
    'test set shape:', test_mm.shape
)
# Out:
# Standardized train set shape: (7315, 23) validation set shape: (1292, 23) test set shape: (1520, 23)
# MinMax scaled train set shape: (7315, 23) validation set shape: (1292, 23) test set shape: (1520, 23)

# %%
print('NA count by column and dataset')

NA_df = pd.DataFrame()
NA_df['train_standardized'] = train_std.isna().sum()
NA_df['validation_standardized'] = val_std.isna().sum()
NA_df['test_standardized'] = test_std.isna().sum()
NA_df['train_minmax'] = train_mm.isna().sum()
NA_df['validation_minmax'] = val_mm.isna().sum()
NA_df['test_minmax'] = test_mm.isna().sum()
NA_df
# Out:
# NA count by column and dataset
#                                train_standardized  validation_standardized  \
# attrition_flag                                  0                        0
# gender_F                                        0                        0
# gender_M                                        0                        0
# education_level_College                         0                        0
# education_level_Doctorate                       0                        0
# education_level_Graduate                        0                        0
# education_level_High School                     0                        0
# education_level_Post-Graduate                   0                        0
# education_level_Uneducated                      0                        0
# education_level_Unknown                         0                        0
# customer_age                                    0                        0
# dependent_count                                 0                        0
# months_on_book                                  0                        0
# total_relationship_count                        0                        0
# months_inactive_12_mon                          0                        0
# contacts_count_12_mon                           0                        0
# credit_limit                                    0                        0
# total_revolving_bal                             0                        0
# total_amt_chng_q4_q1                            0                        0
# total_trans_amt                                 0                        0
# total_trans_ct                                  0                        0
# total_ct_chng_q4_q1                             0                        0
# avg_utilization_ratio                           0                        0
#
#                                test_standardized  train_minmax  \
# attrition_flag                                 0             0
# gender_F                                       0             0
# gender_M                                       0             0
# education_level_College                        0             0
# education_level_Doctorate                      0             0
# education_level_Graduate                       0             0
# education_level_High School                    0             0
# education_level_Post-Graduate                  0             0
# education_level_Uneducated                     0             0
# education_level_Unknown                        0             0
# customer_age                                   0             0
# dependent_count                                0             0
# months_on_book                                 0             0
# total_relationship_count                       0             0
# months_inactive_12_mon                         0             0
# contacts_count_12_mon                          0             0
# credit_limit                                   0             0
# total_revolving_bal                            0             0
# total_amt_chng_q4_q1                           0             0
# total_trans_amt                                0             0
# total_trans_ct                                 0             0
# total_ct_chng_q4_q1                            0             0
# avg_utilization_ratio                          0             0
#
#                                validation_minmax  test_minmax
# attrition_flag                                 0            0
# gender_F                                       0            0
# gender_M                                       0            0
# education_level_College                        0            0
# education_level_Doctorate                      0            0
# education_level_Graduate                       0            0
# education_level_High School                    0            0
# education_level_Post-Graduate                  0            0
# education_level_Uneducated                     0            0
# education_level_Unknown                        0            0
# customer_age                                   0            0
# dependent_count                                0            0
# months_on_book                                 0            0
# total_relationship_count                       0            0
# months_inactive_12_mon                         0            0
# contacts_count_12_mon                          0            0
# credit_limit                                   0            0
# total_revolving_bal                            0            0
# total_amt_chng_q4_q1                           0            0
# total_trans_amt                                0            0
# total_trans_ct                                 0            0
# total_ct_chng_q4_q1                            0            0
# avg_utilization_ratio                          0            0

# %% [markdown]
# **Observation**
# - Datasets have `23` columns (target included) as well it was already divided into train set with `7315` rows, validation set with `1292` rows and test set with `1520` rows `(0.7225 : 0.1275 : 0.15)`
# - Initially, there were `0` missing values in data and missing values have not occurred in any of the three splits from bug during preprocessing

# %% [markdown]
# ### Separate target

# %%
X_train_std, y_train_std = train_std.drop(columns=target_col), train_std[target_name]
X_val_std, y_val_std = val_std.drop(columns=target_col), val_std[target_name]
X_test_std, y_test_std = test_std.drop(columns=target_col), test_std[target_name]

X_train_mm, y_train_mm = train_mm.drop(columns=target_col), train_mm[target_name]
X_val_mm, y_val_mm = val_mm.drop(columns=target_col), val_mm[target_name]
X_test_mm, y_test_mm = test_mm.drop(columns=target_col), test_mm[target_name]

# %% [markdown]
# ### Modeling

# %%
std_models = do_modeling(X_train_std, y_train_std)
mm_models = do_modeling(X_train_mm, y_train_mm)

# %%
std_models, mm_models
# Out:
# ({'Decision Tree': DecisionTreeClassifier(class_weight='balanced', random_state=42),
#   'Random Forest': RandomForestClassifier(class_weight='balanced', random_state=42),
#   'Logistic Regression': LogisticRegression(class_weight='balanced', random_state=42),
#   'Support Vector Machine': SVC(class_weight='balanced', random_state=42)},
#  {'Decision Tree': DecisionTreeClassifier(class_weight='balanced', random_state=42),
#   'Random Forest': RandomForestClassifier(class_weight='balanced', random_state=42),
#   'Logistic Regression': LogisticRegression(class_weight='balanced', random_state=42),
#   'Support Vector Machine': SVC(class_weight='balanced', random_state=42)})

# %% [markdown]
# ### Model selection

# %%
std_eval_report = get_evaluation_report(std_models, X_val_std, y_val_std)
mm_eval_report = get_evaluation_report(mm_models, X_val_mm, y_val_mm)

# %%
std_eval_report.style.background_gradient(cmap=report_cmap)
# Out:
# <style type="text/css">
# #T_312c5_row0_col2, #T_312c5_row4_col2 {
#   background-color: #13266f;
#   color: #f1f1f1;
# }
# #T_312c5_row0_col3 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_312c5_row0_col4 {
#   background-color: #0f2367;
#   color: #f1f1f1;
# }
# #T_312c5_row1_col2 {
#   background-color: #1e86bb;
#   color: #f1f1f1;
# }
# #T_312c5_row1_col3, #T_312c5_row5_col2, #T_312c5_row5_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_312c5_row1_col4 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_312c5_row2_col2 {
#   background-color: #12256d;
#   color: #f1f1f1;
# }
# #T_312c5_row2_col3, #T_312c5_row2_col4, #T_312c5_row6_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_312c5_row3_col2 {
#   background-color: #243392;
#   color: #f1f1f1;
# }
# #T_312c5_row3_col3 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_312c5_row3_col4 {
#   background-color: #1d90c0;
#   color: #f1f1f1;
# }
# #T_312c5_row4_col3 {
#   background-color: #78cbbc;
#   color: #000000;
# }
# #T_312c5_row4_col4 {
#   background-color: #234fa1;
#   color: #f1f1f1;
# }
# #T_312c5_row5_col3 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_312c5_row6_col3 {
#   background-color: #1e88bc;
#   color: #f1f1f1;
# }
# #T_312c5_row6_col4 {
#   background-color: #1b2c80;
#   color: #f1f1f1;
# }
# #T_312c5_row7_col2 {
#   background-color: #a5dcb7;
#   color: #000000;
# }
# #T_312c5_row7_col3 {
#   background-color: #269bc1;
#   color: #f1f1f1;
# }
# #T_312c5_row7_col4 {
#   background-color: #7acbbc;
#   color: #000000;
# }
# </style>
# <table id="T_312c5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >algorithm</th>
#       <th class="col_heading level0 col1" >class</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >f1</th>
#       <th class="col_heading level0 col5" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_312c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_312c5_row0_col0" class="data row0 col0" >Decision Tree</td>
#       <td id="T_312c5_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_312c5_row0_col2" class="data row0 col2" >0.954421</td>
#       <td id="T_312c5_row0_col3" class="data row0 col3" >0.965867</td>
#       <td id="T_312c5_row0_col4" class="data row0 col4" >0.960110</td>
#       <td id="T_312c5_row0_col5" class="data row0 col5" >1084</td>
#     </tr>
#     <tr>
#       <th id="T_312c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_312c5_row1_col0" class="data row1 col0" >Decision Tree</td>
#       <td id="T_312c5_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_312c5_row1_col2" class="data row1 col2" >0.810256</td>
#       <td id="T_312c5_row1_col3" class="data row1 col3" >0.759615</td>
#       <td id="T_312c5_row1_col4" class="data row1 col4" >0.784119</td>
#       <td id="T_312c5_row1_col5" class="data row1 col5" >208</td>
#     </tr>
#     <tr>
#       <th id="T_312c5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_312c5_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_312c5_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_312c5_row2_col2" class="data row2 col2" >0.957066</td>
#       <td id="T_312c5_row2_col3" class="data row2 col3" >0.987085</td>
#       <td id="T_312c5_row2_col4" class="data row2 col4" >0.971844</td>
#       <td id="T_312c5_row2_col5" class="data row2 col5" >1084</td>
#     </tr>
#     <tr>
#       <th id="T_312c5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_312c5_row3_col0" class="data row3 col0" >Random Forest</td>
#       <td id="T_312c5_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_312c5_row3_col2" class="data row3 col2" >0.919540</td>
#       <td id="T_312c5_row3_col3" class="data row3 col3" >0.769231</td>
#       <td id="T_312c5_row3_col4" class="data row3 col4" >0.837696</td>
#       <td id="T_312c5_row3_col5" class="data row3 col5" >208</td>
#     </tr>
#     <tr>
#       <th id="T_312c5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_312c5_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_312c5_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_312c5_row4_col2" class="data row4 col2" >0.955301</td>
#       <td id="T_312c5_row4_col3" class="data row4 col3" >0.847786</td>
#       <td id="T_312c5_row4_col4" class="data row4 col4" >0.898338</td>
#       <td id="T_312c5_row4_col5" class="data row4 col5" >1084</td>
#     </tr>
#     <tr>
#       <th id="T_312c5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_312c5_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_312c5_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_312c5_row5_col2" class="data row5 col2" >0.500000</td>
#       <td id="T_312c5_row5_col3" class="data row5 col3" >0.793269</td>
#       <td id="T_312c5_row5_col4" class="data row5 col4" >0.613383</td>
#       <td id="T_312c5_row5_col5" class="data row5 col5" >208</td>
#     </tr>
#     <tr>
#       <th id="T_312c5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_312c5_row6_col0" class="data row6 col0" >Support Vector Machine</td>
#       <td id="T_312c5_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_312c5_row6_col2" class="data row6 col2" >0.978109</td>
#       <td id="T_312c5_row6_col3" class="data row6 col3" >0.906827</td>
#       <td id="T_312c5_row6_col4" class="data row6 col4" >0.941120</td>
#       <td id="T_312c5_row6_col5" class="data row6 col5" >1084</td>
#     </tr>
#     <tr>
#       <th id="T_312c5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_312c5_row7_col0" class="data row7 col0" >Support Vector Machine</td>
#       <td id="T_312c5_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_312c5_row7_col2" class="data row7 col2" >0.648084</td>
#       <td id="T_312c5_row7_col3" class="data row7 col3" >0.894231</td>
#       <td id="T_312c5_row7_col4" class="data row7 col4" >0.751515</td>
#       <td id="T_312c5_row7_col5" class="data row7 col5" >208</td>
#     </tr>
#   </tbody>
# </table>

# %%
mm_eval_report.style.background_gradient(cmap=report_cmap)
# Out:
# <style type="text/css">
# #T_3d52b_row0_col2 {
#   background-color: #0e2265;
#   color: #f1f1f1;
# }
# #T_3d52b_row0_col3 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_3d52b_row0_col4 {
#   background-color: #0f2367;
#   color: #f1f1f1;
# }
# #T_3d52b_row1_col2 {
#   background-color: #1f7eb7;
#   color: #f1f1f1;
# }
# #T_3d52b_row1_col3, #T_3d52b_row5_col2, #T_3d52b_row5_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_3d52b_row1_col4 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_3d52b_row2_col2, #T_3d52b_row4_col2 {
#   background-color: #0d2163;
#   color: #f1f1f1;
# }
# #T_3d52b_row2_col3, #T_3d52b_row2_col4, #T_3d52b_row6_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_3d52b_row3_col2 {
#   background-color: #1e2e85;
#   color: #f1f1f1;
# }
# #T_3d52b_row3_col3 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_3d52b_row3_col4 {
#   background-color: #1d90c0;
#   color: #f1f1f1;
# }
# #T_3d52b_row4_col3 {
#   background-color: #7acbbc;
#   color: #000000;
# }
# #T_3d52b_row4_col4 {
#   background-color: #234fa1;
#   color: #f1f1f1;
# }
# #T_3d52b_row5_col3 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_3d52b_row6_col3 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# #T_3d52b_row6_col4 {
#   background-color: #253795;
#   color: #f1f1f1;
# }
# #T_3d52b_row7_col2 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_3d52b_row7_col3 {
#   background-color: #73c8bd;
#   color: #000000;
# }
# #T_3d52b_row7_col4 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# </style>
# <table id="T_3d52b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >algorithm</th>
#       <th class="col_heading level0 col1" >class</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >f1</th>
#       <th class="col_heading level0 col5" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d52b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d52b_row0_col0" class="data row0 col0" >Decision Tree</td>
#       <td id="T_3d52b_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_3d52b_row0_col2" class="data row0 col2" >0.954463</td>
#       <td id="T_3d52b_row0_col3" class="data row0 col3" >0.966790</td>
#       <td id="T_3d52b_row0_col4" class="data row0 col4" >0.960587</td>
#       <td id="T_3d52b_row0_col5" class="data row0 col5" >1084</td>
#     </tr>
#     <tr>
#       <th id="T_3d52b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d52b_row1_col0" class="data row1 col0" >Decision Tree</td>
#       <td id="T_3d52b_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_3d52b_row1_col2" class="data row1 col2" >0.814433</td>
#       <td id="T_3d52b_row1_col3" class="data row1 col3" >0.759615</td>
#       <td id="T_3d52b_row1_col4" class="data row1 col4" >0.786070</td>
#       <td id="T_3d52b_row1_col5" class="data row1 col5" >208</td>
#     </tr>
#     <tr>
#       <th id="T_3d52b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d52b_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_3d52b_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_3d52b_row2_col2" class="data row2 col2" >0.957105</td>
#       <td id="T_3d52b_row2_col3" class="data row2 col3" >0.988007</td>
#       <td id="T_3d52b_row2_col4" class="data row2 col4" >0.972310</td>
#       <td id="T_3d52b_row2_col5" class="data row2 col5" >1084</td>
#     </tr>
#     <tr>
#       <th id="T_3d52b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d52b_row3_col0" class="data row3 col0" >Random Forest</td>
#       <td id="T_3d52b_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_3d52b_row3_col2" class="data row3 col2" >0.924855</td>
#       <td id="T_3d52b_row3_col3" class="data row3 col3" >0.769231</td>
#       <td id="T_3d52b_row3_col4" class="data row3 col4" >0.839895</td>
#       <td id="T_3d52b_row3_col5" class="data row3 col5" >208</td>
#     </tr>
#     <tr>
#       <th id="T_3d52b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d52b_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_3d52b_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_3d52b_row4_col2" class="data row4 col2" >0.957292</td>
#       <td id="T_3d52b_row4_col3" class="data row4 col3" >0.847786</td>
#       <td id="T_3d52b_row4_col4" class="data row4 col4" >0.899217</td>
#       <td id="T_3d52b_row4_col5" class="data row4 col5" >1084</td>
#     </tr>
#     <tr>
#       <th id="T_3d52b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3d52b_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_3d52b_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_3d52b_row5_col2" class="data row5 col2" >0.503012</td>
#       <td id="T_3d52b_row5_col3" class="data row5 col3" >0.802885</td>
#       <td id="T_3d52b_row5_col4" class="data row5 col4" >0.618519</td>
#       <td id="T_3d52b_row5_col5" class="data row5 col5" >208</td>
#     </tr>
#     <tr>
#       <th id="T_3d52b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3d52b_row6_col0" class="data row6 col0" >Support Vector Machine</td>
#       <td id="T_3d52b_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_3d52b_row6_col2" class="data row6 col2" >0.968687</td>
#       <td id="T_3d52b_row6_col3" class="data row6 col3" >0.884686</td>
#       <td id="T_3d52b_row6_col4" class="data row6 col4" >0.924783</td>
#       <td id="T_3d52b_row6_col5" class="data row6 col5" >1084</td>
#     </tr>
#     <tr>
#       <th id="T_3d52b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3d52b_row7_col0" class="data row7 col0" >Support Vector Machine</td>
#       <td id="T_3d52b_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_3d52b_row7_col2" class="data row7 col2" >0.586093</td>
#       <td id="T_3d52b_row7_col3" class="data row7 col3" >0.850962</td>
#       <td id="T_3d52b_row7_col4" class="data row7 col4" >0.694118</td>
#       <td id="T_3d52b_row7_col5" class="data row7 col5" >208</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observation**
# - For churn prediction, recall is considered as first choice of metric for model evaluation to select model with maximum ability to detect churn customers
# - Support vector machine (SVM) algorithm with input standardization preprocessing has outperformed other models in churn prediction task on this dataset. Hence, SVM algorithm will be furthur tuned

# %% [markdown]
# ### Tuning

# %%
params = dict(
    C=10 ** arange(-4, 2.5, 0.5)
)

scorer = make_scorer(recall_score, average='binary')

clf = RandomizedSearchCV(
    SVC(class_weight='balanced', random_state=seed),
    params,
    random_state=seed,
    cv=5,
    n_jobs=-1,
    scoring=scorer,
    n_iter=15
)

# %%
X_train_val_std = pd.concat([X_train_std, X_val_std])
y_train_val_std = pd.concat([y_train_std, y_val_std])

fitted = clf.fit(X_train_val_std, y_train_val_std)
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 13 is smaller than n_iter=15. Running 13 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(

# %%
fitted.best_estimator_
# Out:
# SVC(C=0.31622776601683794, class_weight='balanced', random_state=42)

# %%
fitted.best_score_
# Out:
# 0.8994872599801182

# %% [markdown]
# ### Evaluation

# %%
preds = fitted.best_estimator_.predict(X_test_std)
print(classification_report(y_test_std, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93      1276
#            1       0.62      0.90      0.73       244
#
#     accuracy                           0.90      1520
#    macro avg       0.80      0.90      0.83      1520
# weighted avg       0.92      0.90      0.90      1520

# %%
train_preds = fitted.best_estimator_.predict(X_train_val_std)
print(classification_report(y_train_val_std, train_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95      7224
#            1       0.67      0.94      0.79      1383
#
#     accuracy                           0.92      8607
#    macro avg       0.83      0.93      0.87      8607
# weighted avg       0.94      0.92      0.92      8607

# %% [markdown]
# **Observation**
# - Parameter tuning helped obtaining a model that is better than model with default settings on validation set
# - Model performance on testing set (first report) is not too far from training set (last report). Hence, it can be said that model is not memorizing training data

# %% [markdown]
# ### Prediction

# %%
X_test_std[prediction_column] = preds

# %%
pd.concat([X_test_std[prediction_column], y_test_std], axis=1).sample(15)
# Out:
#            prediction  attrition_flag
# clientnum
# 794664183           0               0
# 712665633           1               0
# 712390683           0               0
# 713497983           1               0
# 708860358           0               0
# 719625933           0               0
# 813182658           0               0
# 708811233           0               0
# 715957233           0               0
# 719944458           0               0
# 713390433           1               1
# 771752508           0               0
# 778921908           0               0
# 799711833           0               0
# 820925433           0               0

# %% [markdown]
# ### Serialization

# %%
joblib.dump(fitted.best_estimator_, f"{output_dir}/{model_fname}")
# Out:
# ['outputs/model.joblib']
